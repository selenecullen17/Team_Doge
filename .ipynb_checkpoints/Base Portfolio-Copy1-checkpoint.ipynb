# %% [markdown]
# # Portfolio Contents
#
# I want to choose a couple of stock ETFs and Bond ETFs. To make things more tailored to me/people my age I'm going to pick some ETFs that are a little "Interesting", instead of just going with straightforward asset classes. Here is the list of ETFs that I am considering using:
# - SPDR Gender Diversity ETF (SHE)
# - ARKK Innovation ETF (ARKK)
# - iShares MSCI Emerging Markets ETF (EEM)
# - iShares iBoxx High Yield Corporate Bond ETF (HYG)
# - Vanguard Mega Cap Index Fund ETF Shares (MGC)
# - iShares U.S. Real Estate ETF (IYR)
# - iShares 1-3 Year Treasury Bond ETF (SHY)
# - Consumer Staples Select Sector SPDR Fund (XLP)
# - SPDR Gold Shares (GLD)
# - Global X Lithium & Battery Tech ETF (LIT)
#
# I'm going to create a portfolio of these funds and use SPY as comparison to find the $\Beta$ of the portfolio (as well as other stats). For the portfolio weights, I am going to find the maximum sharpe ratio.

# %%
import pandas as pd                                    # Working with tables
import numpy as np

from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'349dd4117e5d1ed71a22f0207a8e439cf3f7b06b'})
quandl.ApiConfig.api_key = '_ci7hzC_sPkspKWz2yzt'                      # Replace the XXXX with your API key (must be inside the ' ').

import matplotlib.pyplot as plt                        # Basic plot library.
plt.style.use('ggplot')                                # Make plots look nice.
# %matplotlib inline

# %%
tickers = ['SHE','ARKK','EEM','HYG','MGC','IYR','SHY','XLP','GLD','LIT']
prices  = tiingo.get_dataframe(tickers, '2016-3-8', metric_name='adjClose')
prices.index = pd.to_datetime(prices.index).tz_convert(None)    # Get rid of hour, minutes, seconds in the row i
prices
spy = tiingo.get_dataframe('SPY', '2016-3-8', metric_name='adjClose')
spy.index = pd.to_datetime(spy.index).tz_convert(None)

# %%
spy.to_csv("C:\\Users\\selen\\Practicum Project\\spy.csv")

# %%
r = prices.pct_change()
r
# Out:
#                  SHE      ARKK       EEM       HYG       MGC       IYR  \
# 2016-03-08       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-03-09 -0.000498 -0.012603  0.006209  0.002488  0.003829  0.004064
# 2016-03-10 -0.000268 -0.009266  0.001543  0.006948  0.000883 -0.002563
# 2016-03-11  0.016500  0.006546  0.020949  0.012075  0.016762  0.023671
# 2016-03-14 -0.000066  0.026213 -0.006035 -0.002800 -0.000868 -0.001321
# ...              ...       ...       ...       ...       ...       ...
# 2022-01-14 -0.004406  0.003251 -0.000399 -0.000928  0.001159 -0.009516
# 2022-01-18 -0.016466 -0.041500 -0.017761 -0.004879 -0.017549 -0.008967
# 2022-01-19 -0.004395 -0.015083  0.004267 -0.000934 -0.009924 -0.012557
# 2022-01-20 -0.011140  0.001584  0.005867 -0.001869 -0.010775 -0.012436
# 2022-01-21 -0.033797 -0.057335 -0.014481  0.000117 -0.020328 -0.002367
#
#                  SHY       XLP       GLD       LIT
# 2016-03-08       NaN       NaN       NaN       NaN
# 2016-03-09 -0.000354  0.007519 -0.008293  0.003497
# 2016-03-10 -0.000118  0.000383  0.016056 -0.004973
# 2016-03-11 -0.000944  0.003252 -0.017202  0.037013
# 2016-03-14  0.000000 -0.000572 -0.012897  0.004824
# ...              ...       ...       ...       ...
# 2022-01-14 -0.001290  0.001821 -0.002880  0.004464
# 2022-01-18 -0.001526 -0.014410 -0.001650 -0.008167
# 2022-01-19  0.000470  0.006322  0.015881 -0.026278
# 2022-01-20 -0.000235 -0.006545 -0.002499 -0.003109
# 2022-01-21  0.000823  0.000791 -0.003262 -0.016717
#
# [1481 rows x 10 columns]

# %%
rf = 0.011
risk_premiums = r.mean() * 252 - rf       
vol           = r.std()  * 252**0.5
cov           = r.cov()  * 252    
corr          = r.corr() 
cov.to_csv("C:\\Users\\selen\\Practicum Project\\cov.csv")
#vol.to_csv("C:\\Users\\selen\\Practicum Project\\vol.csv")
#r.to_csv("C:\\Users\\selen\\Practicum Project\\r.csv")

# %%
cov_inv = pd.DataFrame(np.linalg.pinv(cov.values), cov.columns, cov.index)
cov_inv
# Out:
#              SHE       ARKK        EEM         HYG         MGC         IYR  \
# SHE   339.347670 -13.135632   8.970676   -7.950799 -262.741818  -39.741392
# ARKK  -13.135632  25.111263  -2.714799    5.957415  -31.426787    2.343438
# EEM     8.970676  -2.714799  74.684408  -28.136743  -49.489039    2.544432
# HYG    -7.950799   5.957415 -28.136743  430.914649  -83.231397  -59.303304
# MGC  -262.741818 -31.426787 -49.489039  -83.231397  471.121326    4.865730
# IYR   -39.741392   2.343438   2.544432  -59.303304    4.865730   75.631025
# SHY   223.122305 -61.348584  -5.911351  -50.114106  295.581530 -224.784183
# XLP    -1.664998  21.801281   6.879712   16.195157 -112.254175  -28.673649
# GLD    -3.009119  -2.197558  -8.214113   -8.206163   18.313461    1.125576
# LIT    -7.104071  -4.927299 -17.649676   -7.640220   -3.144686   -0.648064
#
#                SHY         XLP         GLD        LIT
# SHE     223.122305   -1.664998   -3.009119  -7.104071
# ARKK    -61.348584   21.801281   -2.197558  -4.927299
# EEM      -5.911351    6.879712   -8.214113 -17.649676
# HYG     -50.114106   16.195157   -8.206163  -7.640220
# MGC     295.581530 -112.254175   18.313461  -3.144686
# IYR    -224.784183  -28.673649    1.125576  -0.648064
# SHY   14215.463214  -51.651808 -332.694838  46.947792
# XLP     -51.651808  142.453150  -10.954260   4.749290
# GLD    -332.694838  -10.954260   65.284206  -2.502441
# LIT      46.947792    4.749290   -2.502441  29.799034

# %%
w_max_Sharpe = cov_inv.dot(risk_premiums)/sum(cov_inv.dot(risk_premiums))
w_max_Sharpe
# Out:
# SHE    -0.323865
# ARKK    0.030482
# EEM    -0.152894
# HYG    -0.020454
# MGC     0.468875
# IYR    -0.027008
# SHY     0.869232
# XLP     0.000159
# GLD     0.063457
# LIT     0.092016
# dtype: float64

# %%
  # mean - volatility table
assets = pd.DataFrame()                        
assets['Risk_premium'] = risk_premiums
assets['Volatility']   = vol    
assets['Color']        = 'orange'
assets['Size']         = 150

all_portfolios = assets

graph = all_portfolios.plot.scatter('Volatility','Risk_premium', color=all_portfolios.Color, s=all_portfolios.Size, xlim=(0,0.5), ylim=(-0.03,0.5))

# add ticker symbols to plot:
for s in tickers:                                 # loop over sectors
    x = all_portfolios.loc[s,'Volatility']+0.005  # get x-coordinate from table (+ offset so the labels don't overlap with points)
    y = all_portfolios.loc[s,'Risk_premium']      # get y-coordinate from table
    graph.text(x,y,s)                             # add the ticker symbol to the graph

# %%
n_portfolios = 1000

random_arrays  = [ np.random.uniform(0,1,len(tickers)) for i in range(0,n_portfolios) ]
random_weights = [ ra/ra.sum() for ra in random_arrays ]

random = pd.DataFrame()
random['Risk_premium'] = [ w.dot(risk_premiums)   for w in random_weights ]
random['Volatility']   = [ w.dot(cov).dot(w)**0.5 for w in random_weights ]
random['Color']        = 'gray'
random['Size']         = 10
random['sharpe']       = random['Risk_premium']/random['Volatility']

all_portfolios = pd.concat([random, assets])

graph = all_portfolios.plot.scatter('Volatility','Risk_premium', color=all_portfolios.Color, s=all_portfolios.Size, xlim=(0,0.5), ylim=(-0.03,0.5))

# add ticker to plot:
for s in tickers:                                 # loop over sectors
    x = all_portfolios.loc[s,'Volatility']+0.005  # get x-coordinate from table (+ offset so the labels don't overlap with points)
    y = all_portfolios.loc[s,'Risk_premium']      # get y-coordinate from table
    graph.text(x,y,s)                             # add the ticker symbol to the graph

# %%
random[(random['Risk_premium']>= .1)][(random['Volatility']<= .17)].sharpe.max()
# Out:
# <ipython-input-14-8940feeb32bb>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   random[(random['Risk_premium']>= .1)][(random['Volatility']<= .17)].sharpe.max()
# 1.0401502513591419

# %%
random['weights'] = random_weights
random
# Out:
#      Risk_premium  Volatility Color  Size    sharpe  \
# 0        0.143243    0.152900  gray    10  0.936840
# 1        0.147367    0.159460  gray    10  0.924163
# 2        0.152186    0.163679  gray    10  0.929779
# 3        0.104971    0.118903  gray    10  0.882829
# 4        0.134102    0.146812  gray    10  0.913429
# ..            ...         ...   ...   ...       ...
# 995      0.117052    0.139334  gray    10  0.840080
# 996      0.142927    0.152104  gray    10  0.939664
# 997      0.131804    0.152355  gray    10  0.865112
# 998      0.117401    0.129369  gray    10  0.907487
# 999      0.147500    0.170679  gray    10  0.864197
#
#                                                weights
# 0    [0.14494324482171123, 0.16711934013059332, 0.0...
# 1    [0.14680754703781407, 0.17269800235034266, 0.0...
# 2    [0.16366040734680115, 0.15794839316001022, 0.0...
# 3    [0.12763064440997776, 0.05435749900502422, 0.0...
# 4    [0.14888926807965217, 0.09249363751419483, 0.0...
# ..                                                 ...
# 995  [0.13297917840648127, 0.0485398196666207, 0.16...
# 996  [0.06794384378850986, 0.13730843889086425, 0.0...
# 997  [0.034486973410382225, 0.1241554443847141, 0.1...
# 998  [0.09933749315097165, 0.13825530159594884, 0.0...
# 999  [0.2365960563143532, 0.0836390815413474, 0.097...
#
# [1000 rows x 6 columns]

# %%
wgts = random[(random['sharpe'] >= random.sharpe.max())].weights.astype(str)

wgts
rp = random[(random['sharpe'] == random.sharpe.max())].Risk_premium

# %%
lw = list(wgts)
ws = str(lw[0])
ws = ws.replace('[','')
ws = ws.replace(']','')
lw = ws.split(' ')
lw = list(filter(None, lw))
nw = np.array(lw)
nw = nw.astype(float)
nw
# Out:
# array([0.05049055, 0.13164644, 0.00103162, 0.05062037, 0.08807752,
#        0.08842996, 0.1362119 , 0.00949493, 0.21238298, 0.23161374])

# %%
t = pd.DataFrame()
t['Risk_Premiums'] = risk_premiums
t['Weights'] = nw
t['weighted_ret'] = t['Weights']*t['Risk_Premiums']
t.to_csv("C:\\Users\\selen\\Downloads\\weights.csv")

# %%
mrp = t['weighted_ret'].sum()
mrp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-55d5744d5623> in <module>
# ----> 1 mrp = t['weighted_ret'].sum()
#       2 mrp
#
# NameError: name 't' is not defined

# %%
r = r.dot(t['Weights'])
r
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-3abca5fad78d> in <module>
# ----> 1 r = r.dot(t['Weights'])
#       2 r
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in dot(self, other)
#    1183             common = self.columns.union(other.index)
#    1184             if len(common) > len(self.columns) or len(common) > len(other.index):
# -> 1185                 raise ValueError("matrices are not aligned")
#    1186
#    1187             left = self.reindex(columns=common, copy=False)
#
# ValueError: matrices are not aligned

# %%
r['total_ret'] = r.sum(axis=1)
r
# Out:
#                 ARKK           EEM       GLD           HYG           IYR  \
# 2016-03-08       NaN           NaN       NaN           NaN           NaN
# 2016-03-09 -0.000026  2.170011e-10 -0.000010  3.796583e-09  7.857692e-12
# 2016-03-10 -0.000019  5.391549e-11  0.000019  1.060405e-08 -4.956396e-12
# 2016-03-11  0.000014  7.321212e-10 -0.000021  1.842905e-08  4.576834e-11
# 2016-03-14  0.000054 -2.109114e-10 -0.000015 -4.273582e-09 -2.554858e-12
# ...              ...           ...       ...           ...           ...
# 2022-01-13 -0.000112 -4.948392e-10 -0.000004 -5.470978e-09 -6.113747e-12
# 2022-01-14  0.000007 -1.394296e-11 -0.000003 -1.416945e-09 -1.839942e-11
# 2022-01-18 -0.000086 -6.207092e-10 -0.000002 -7.445871e-09 -1.733778e-11
# 2022-01-19 -0.000031  1.491078e-10  0.000019 -1.425214e-09 -2.427829e-11
# 2022-01-20  0.000003  2.050359e-10 -0.000003 -2.853093e-09 -2.404466e-11
#
#                  LIT           MGC           SHE           SHY           XLP  \
# 2016-03-08       NaN           NaN           NaN           NaN           NaN
# 2016-03-09  0.000008  2.710798e-07 -8.759819e-09 -1.724147e-11  2.400353e-07
# 2016-03-10 -0.000011  6.251059e-08 -4.707789e-09 -5.749191e-12  1.221764e-08
# 2016-03-11  0.000080  1.186653e-06  2.900952e-07 -4.599896e-11  1.038102e-07
# 2016-03-14  0.000010 -6.142581e-08 -1.165437e-09  0.000000e+00 -1.826007e-08
# ...              ...           ...           ...           ...           ...
# 2022-01-13 -0.000055 -1.142992e-06 -2.835772e-07  2.285917e-11  5.823397e-08
# 2022-01-14  0.000010  8.205659e-08 -7.746073e-08 -6.283324e-11  5.812794e-08
# 2022-01-18 -0.000018 -1.242365e-06 -2.895014e-07 -7.435337e-11 -4.600339e-07
# 2022-01-19 -0.000057 -7.025317e-07 -7.726640e-08  2.291293e-11  2.018421e-07
# 2022-01-20 -0.000007 -7.627913e-07 -1.958664e-07 -1.145108e-11 -2.089312e-07
#
#             total_ret
# 2016-03-08   0.000000
# 2016-03-09  -0.000028
# 2016-03-10  -0.000011
# 2016-03-11   0.000075
# 2016-03-14   0.000049
# ...               ...
# 2022-01-13  -0.000173
# 2022-01-14   0.000013
# 2022-01-18  -0.000107
# 2022-01-19  -0.000070
# 2022-01-20  -0.000008
#
# [1480 rows x 11 columns]

# %%
#find Beta
total = r['total_ret']
rf = 0.011
risk_premium = total.mean() * 252 - rf       
vol           = total.std()  * 252**0.5
vol
risk_premium
# Out:
# 0.02934317988149464
